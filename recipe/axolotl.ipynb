# %%
import time
import cv2
import IPython.display
import PIL.Image
sea = cv2.imread('images/axolotl.jpg')
sea = cv2.cvtColor(sea, cv2.COLOR_BGR2RGB)
sea = cv2.resize(sea,(800,450))
IPython.display.display(PIL.Image.fromarray(sea))
# Put your code under here. You can delete the intro if it's annoying you ;)
# Out:
# <PIL.Image.Image image mode=RGB size=800x450 at 0x9EC2B430>
