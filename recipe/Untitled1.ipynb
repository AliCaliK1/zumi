# %%
import cv2
import IPython.display
import PIL.Image
me = cv2.imread('hi.jpg')
me = cv2.cvtColor(me, cv2.COLOR_BGR2RGB)
cv2.circle(me,(420,175), 23, (255,0,0), -1)
cv2.circle(me,(280,165), 24, (255,0,0), -1)
IPython.display.display(PIL.Image.fromarray(me))
# Out:
# <PIL.Image.Image image mode=RGB size=720x480 at 0x9EB5C510>
